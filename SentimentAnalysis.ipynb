# %%
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: tweepy in /home/naruto/anaconda3/lib/python3.7/site-packages (3.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/naruto/anaconda3/lib/python3.7/site-packages (from tweepy) (1.0.0)
# Requirement already satisfied: six>=1.10.0 in /home/naruto/anaconda3/lib/python3.7/site-packages (from tweepy) (1.11.0)
# Requirement already satisfied: PySocks>=1.5.7 in /home/naruto/anaconda3/lib/python3.7/site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests>=2.11.1 in /home/naruto/anaconda3/lib/python3.7/site-packages (from tweepy) (2.21.0)
# Requirement already satisfied: oauthlib>=0.6.2 in /home/naruto/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/naruto/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2018.8.24)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/naruto/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/naruto/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2.7)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/naruto/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (1.23)
# You are using pip version 10.0.1, however version 19.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 284kB/s ta 0:00:01
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1
# You are using pip version 10.0.1, however version 19.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /home/naruto/anaconda3/lib/python3.7/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
consumer_key="EcLvLVGT6uOSd1RaHHtSMy37Q"
consumer_secret="smn4W8IoubA9jmoGY5WZBxrNG1w4iZWtOG0Z1fsPqhaYIeI9qT"
access_token="858313360869404672-BAfahq9LHFu8pvMat24OXZuARH8JKpH"
access_token_secret="kzdIkLDB4YSvGaeSYJEUqN9Tv9QWyklC4JevfAtjlXTsa"

# %%
auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api=tweepy.API(auth)

# %%
tweets=api.search('Artificial Intelligence',count=200)
data=pd.DataFrame(data=[tweet.text for tweet in tweets],columns=['Tweets'])
display(data.head(10))
# Out:
#                                               Tweets
# 0  Artificial Super intelligence   How close are ...
# 1         RT @1st_relationn: https://t.co/fx8QapKRL5
# 2         RT @norwayspariss: https://t.co/KpJP7nr1n8
# 3  This could be brilliant - an awesome use of Ar...
# 4  This might be brilliant - another awesome use ...
# 5  What the new artificial intelligence initiativ...
# 6  Trump Is Ordering Federal Agencies to Prioriti...
# 7  This might be brilliant - another awesome use ...
# 8  RT @rafiziramli: Hundreds of people had gone t...
# 9  This could be brilliant - an awesome use of AI...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/naruto/nltk_data...
# True

# %%
sid=SentimentIntensityAnalyzer()

# %%
mylist=[]
for index,row in data.iterrows():
    pol=sid.polarity_scores(row["Tweets"])
    mylist.append(pol)

pol=pd.Series(mylist)
data['polarity']=pol.values
# Out:
#                                               Tweets  \
# 0  Artificial Super intelligence   How close are ...
# 1         RT @1st_relationn: https://t.co/fx8QapKRL5
# 2         RT @norwayspariss: https://t.co/KpJP7nr1n8
# 3  This could be brilliant - an awesome use of Ar...
# 4  This might be brilliant - another awesome use ...
#
#                                             polarity
# 0  {'neg': 0.0, 'neu': 0.533, 'pos': 0.467, 'comp...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 0.593, 'pos': 0.407, 'comp...
# 4  {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'comp...

# %%
display(data.head(50))
# Out:
#                                                Tweets  \
# 0   Artificial Super intelligence   How close are ...
# 1          RT @1st_relationn: https://t.co/fx8QapKRL5
# 2          RT @norwayspariss: https://t.co/KpJP7nr1n8
# 3   This could be brilliant - an awesome use of Ar...
# 4   This might be brilliant - another awesome use ...
# 5   What the new artificial intelligence initiativ...
# 6   Trump Is Ordering Federal Agencies to Prioriti...
# 7   This might be brilliant - another awesome use ...
# 8   RT @rafiziramli: Hundreds of people had gone t...
# 9   This could be brilliant - an awesome use of AI...
# 10  RT @GideonGil: AI algorithms are 97% accurate ...
# 11  Review on machine learning based artificial in...
# 12  RT @antoniotabet: “Trump wants to spend 5 bill...
# 13  RT @nQHKhXoZTDrDgmj: データグリッドのアイドル自動生成AI https:...
# 14  A crucial step for averting #ArtificialIntelli...
# 15  RT @christi19962006: #datascience #artificiali...
# 16  RT @hbredda: Frase numa Tech Conference: Ameri...
# 17  RT @antoniotabet: “Trump wants to spend 5 bill...
# 18  RT @Desesquerdizada: @antoniotabet China built...
# 19         RT @norwayspariss: https://t.co/ydp2Nktb6w
# 20  Artificial Intelligence can boost efficiency a...
# 21  Instead of just augmenting the technical featu...
# 22  RT @OldBuzzardFeed: The great thing is @rachel...
# 23  Join us at the 2019 CAMO Evening Symposium to ...
# 24  Is Artificial Intelligence the Ultimate Alchem...
# 25  Artificial Intelligence: Hospitality, and That...
# 26         RT @1st_relationn: https://t.co/YyJdiAlgI5
# 27  Businesses should view #AI as a revolutionary ...
# 28          RT @AnimalsPostt: https://t.co/gxBpmfNlzS
# 29  A grimes ta doidona nesse novo filtro\nBiology...
# 30  Une machine peut enfin (presque) terminer vos ...
# 31  Dario Gil Talks to CNN about Project Debater h...
# 32  The Associated Press is Expanding its Use of A...
# 33            Artificial intelligence is the #future.
# 34  RT @mourodrigo: "America wants to invest $5bi ...
# 35  RT @caseymross: He went hunting for gold-stand...
# 36  There are so many questions when it comes to a...
# 37  New research finds that artificial intelligenc...
# 38  7 Awesome Ways In Which Artificial Intelligenc...
# 39  The Defense Department is working with researc...
# 40  RT @meryemtheturk: Can’t Believe Katy just inv...
# 41  I loved speaking with Billee Howard in this po...
# 42  Is Artificial Intelligence the Ultimate Alchem...
# 43  RT @mind_sync: New research finds that artific...
# 44  Check out the latest from @RIXinsights: Virgin...
# 45  "The challenge of creating humanlike intellige...
# 46  Artificial Intelligence with Python Heuristic ...
# 47  Circularity advocates best get comfortable wit...
# 48  @ErikRidley talks to the PACSman Mike Cannavo ...
# 49  RT @Viraj_Martech: How Artificial Intelligence...
#
#                                              polarity
# 0   {'neg': 0.0, 'neu': 0.533, 'pos': 0.467, 'comp...
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3   {'neg': 0.0, 'neu': 0.593, 'pos': 0.407, 'comp...
# 4   {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'comp...
# 5   {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'comp...
# 6   {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...
# 7   {'neg': 0.135, 'neu': 0.59, 'pos': 0.274, 'com...
# 8   {'neg': 0.0, 'neu': 0.837, 'pos': 0.163, 'comp...
# 9   {'neg': 0.135, 'neu': 0.59, 'pos': 0.274, 'com...
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 11  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...
# 12  {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compou...
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 14  {'neg': 0.265, 'neu': 0.735, 'pos': 0.0, 'comp...
# 15  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 16  {'neg': 0.0, 'neu': 0.871, 'pos': 0.129, 'comp...
# 17  {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compou...
# 18  {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compou...
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 20  {'neg': 0.111, 'neu': 0.507, 'pos': 0.382, 'co...
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 22  {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'comp...
# 23  {'neg': 0.0, 'neu': 0.772, 'pos': 0.228, 'comp...
# 24  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compou...
# 25  {'neg': 0.0, 'neu': 0.795, 'pos': 0.205, 'comp...
# 26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 27  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...
# 28  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 29  {'neg': 0.117, 'neu': 0.702, 'pos': 0.181, 'co...
# 30  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 31  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 32  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'comp...
# 33  {'neg': 0.0, 'neu': 0.563, 'pos': 0.437, 'comp...
# 34  {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'comp...
# 35  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...
# 36  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...
# 37  {'neg': 0.104, 'neu': 0.743, 'pos': 0.153, 'co...
# 38  {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'comp...
# 39  {'neg': 0.0, 'neu': 0.914, 'pos': 0.086, 'comp...
# 40  {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'comp...
# 41  {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compou...
# 42  {'neg': 0.0, 'neu': 0.693, 'pos': 0.307, 'comp...
# 43  {'neg': 0.095, 'neu': 0.766, 'pos': 0.14, 'com...
# 44  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'comp...
# 45  {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'comp...
# 46  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 47  {'neg': 0.0, 'neu': 0.459, 'pos': 0.541, 'comp...
# 48  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...
# 49  {'neg': 0.0, 'neu': 0.795, 'pos': 0.205, 'comp...
