# %%
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: tweepy in /home/naruto/anaconda3/lib/python3.7/site-packages (3.7.0)
# Requirement already satisfied: six>=1.10.0 in /home/naruto/anaconda3/lib/python3.7/site-packages (from tweepy) (1.11.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/naruto/anaconda3/lib/python3.7/site-packages (from tweepy) (1.0.0)
# Requirement already satisfied: PySocks>=1.5.7 in /home/naruto/anaconda3/lib/python3.7/site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests>=2.11.1 in /home/naruto/anaconda3/lib/python3.7/site-packages (from tweepy) (2.21.0)
# Requirement already satisfied: oauthlib>=0.6.2 in /home/naruto/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/naruto/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/naruto/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/naruto/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2018.8.24)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/naruto/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (1.23)
# You are using pip version 10.0.1, however version 19.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: vaderSentiment in /home/naruto/anaconda3/lib/python3.7/site-packages (3.2.1)
# You are using pip version 10.0.1, however version 19.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /home/naruto/anaconda3/lib/python3.7/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
consumer_key=""
consumer_secret=""
access_token=""
access_token_secret=""

# %%
auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api=tweepy.API(auth)

# %%
tweets=api.search('Artificial Intelligence',count=200)
data=pd.DataFrame(data=[tweet.text for tweet in tweets],columns=['Tweets'])
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @EU_Commission: We welcome the agreement on...
# 1          RT @LovePoint199: https://t.co/QPYSM9V278
# 2  #EU\n\nWe welcome the agreement on our new Dig...
# 3  RT @GermanyDiplo: Artificial intelligence, aut...
# 4  "oooh katyP, my artificial intelligence is mor...
# 5  Pope discusses ethics of artificial intelligen...
# 6  Technology Lead – US: Role Technology Lead – U...
# 7  We welcome the agreement on our new Digital Eu...
# 8  Come to learn more about artificial intelligen...
# 9  Interesante trabajo sobre #algoritmos que faci...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/naruto/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid=SentimentIntensityAnalyzer()

# %%
mylist=[]
for index,row in data.iterrows():
    pol=sid.polarity_scores(row["Tweets"])
    mylist.append(pol)

pol=pd.Series(mylist)
data['polarity']=pol.values

# %%
display(data.head(50))
# Out:
#                                                Tweets  \
# 0   RT @EU_Commission: We welcome the agreement on...
# 1           RT @LovePoint199: https://t.co/QPYSM9V278
# 2   #EU\n\nWe welcome the agreement on our new Dig...
# 3   RT @GermanyDiplo: Artificial intelligence, aut...
# 4   "oooh katyP, my artificial intelligence is mor...
# 5   Pope discusses ethics of artificial intelligen...
# 6   Technology Lead – US: Role Technology Lead – U...
# 7   We welcome the agreement on our new Digital Eu...
# 8   Come to learn more about artificial intelligen...
# 9   Interesante trabajo sobre #algoritmos que faci...
# 10  RT @jamft: I guess when one lacks natural inte...
# 11  RT @bonnalliance: Apply now! We are looking fo...
# 12  RT @0xDUDE: There is this company in China nam...
# 13  Women should be more engaged in Artificial Int...
# 14  RT @MKTGInsiders: 5 Benefits of AI for Digital...
# 15  RT @AdeccoGroup: “The highest risk we have tod...
# 16  RT @MixnerConsults: #PopeFrancis discusses eth...
# 17  RT @Desesquerdizada: @antoniotabet China built...
# 18  RT @wef: 4 ways AI will impact the financial j...
# 19  RT @GermanyDiplo: Artificial intelligence, aut...
# 20  U.S. Gov launches its first AI Plan, comes beh...
# 21  RT @avantgame: Inside the live action role pla...
# 22  คนที่ทำงานสักแต่ว่าทำไปวันวัน\nแต่งหน้าแต่งตาเ...
# 23  RT @DrAliMonam: Artificial intelligence diagno...
# 24  RT @DrAliMonam: Artificial intelligence diagno...
# 25  RT @rafiziramli: Hundreds of people had gone t...
# 26  RT fabiomoioli: RT AdeccoGroup: “The highest r...
# 27  Will Artificial Intelligence Eat Your Sales Jo...
# 28  RT @GideonGil: AI algorithms are 97% accurate ...
# 29  The director of Microsoft talked with the pope...
# 30  RT @techpearce2: The Role Of Artificial Intell...
# 31  Artificial intelligence diagnoses flu, gastro ...
# 32  RT @GermanyDiplo: Artificial intelligence, aut...
# 33  Artificial Intelligence models may have a few ...
# 34         RT @NaturAmazingg: https://t.co/gnux3nYaOc
# 35  Get the best AI developers , to develop your A...
# 36  RT @GermanyDiplo: Artificial intelligence, aut...
# 37  RT @Desesquerdizada: @antoniotabet China built...
# 38  RT @SUSE: SUSE's own Jeff Reser is creating wo...
# 39  Vatican and Microsoft Team Up on Artificial In...
# 40  The Role Of Artificial Intelligence And Machin...
# 41  https://t.co/rCS0GOvQGH is face-generating #AI...
# 42  RT @Desesquerdizada: @antoniotabet China built...
# 43  Do you think AI will ever replace the need for...
# 44  RT @smashingmag: Ahhh, pretty cool. Using Arti...
# 45  How artificial intelligence is shaking up the ...
# 46  RT @GermanyDiplo: Artificial intelligence, aut...
# 47  ML’s Role in Building Confidence and Value in ...
# 48  Trump to sign executive order promoting artifi...
# 49  Cognitive #Computing: More Human Than #Artific...
#
#                                              polarity
# 0   {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'comp...
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2   {'neg': 0.0, 'neu': 0.754, 'pos': 0.246, 'comp...
# 3   {'neg': 0.269, 'neu': 0.432, 'pos': 0.299, 'co...
# 4   {'neg': 0.182, 'neu': 0.65, 'pos': 0.168, 'com...
# 5   {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...
# 6   {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'comp...
# 7   {'neg': 0.0, 'neu': 0.754, 'pos': 0.246, 'comp...
# 8   {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'comp...
# 9   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 10  {'neg': 0.0, 'neu': 0.712, 'pos': 0.288, 'comp...
# 11  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 12  {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'comp...
# 13  {'neg': 0.0, 'neu': 0.535, 'pos': 0.465, 'comp...
# 14  {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'comp...
# 15  {'neg': 0.201, 'neu': 0.691, 'pos': 0.108, 'co...
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 17  {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compou...
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 19  {'neg': 0.269, 'neu': 0.432, 'pos': 0.299, 'co...
# 20  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 21  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'comp...
# 22  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 23  {'neg': 0.139, 'neu': 0.695, 'pos': 0.166, 'co...
# 24  {'neg': 0.139, 'neu': 0.695, 'pos': 0.166, 'co...
# 25  {'neg': 0.0, 'neu': 0.837, 'pos': 0.163, 'comp...
# 26  {'neg': 0.215, 'neu': 0.785, 'pos': 0.0, 'comp...
# 27  {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'comp...
# 28  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 29  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'comp...
# 30  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...
# 31  {'neg': 0.166, 'neu': 0.637, 'pos': 0.197, 'co...
# 32  {'neg': 0.269, 'neu': 0.432, 'pos': 0.299, 'co...
# 33  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'comp...
# 34  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 35  {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'comp...
# 36  {'neg': 0.269, 'neu': 0.432, 'pos': 0.299, 'co...
# 37  {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compou...
# 38  {'neg': 0.0, 'neu': 0.916, 'pos': 0.084, 'comp...
# 39  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 40  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...
# 41  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 42  {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compou...
# 43  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 44  {'neg': 0.0, 'neu': 0.616, 'pos': 0.384, 'comp...
# 45  {'neg': 0.115, 'neu': 0.676, 'pos': 0.209, 'co...
# 46  {'neg': 0.269, 'neu': 0.432, 'pos': 0.299, 'co...
# 47  {'neg': 0.0, 'neu': 0.678, 'pos': 0.322, 'comp...
# 48  {'neg': 0.0, 'neu': 0.641, 'pos': 0.359, 'comp...
# 49  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
